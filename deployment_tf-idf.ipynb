# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
dataset= pd.read_csv("news.csv", index_col=False)
dataset = dataset.drop("Unnamed: 0", axis=1)
x=dataset['text']
y=dataset['label']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=53)

# %%
tf_idf_vector= TfidfVectorizer()
count_x_train= tf_idf_vector.fit_transform(x_train)
count_x_test = tf_idf_vector.transform(x_test)
print(count_x_train)
count_x_train
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 1450513 stored elements and shape (4244, 57227)>
#   Coords	Values
#   (1, 42669)	0.07057387482199357
#   (1, 12165)	0.13735856202479088
#   (1, 54448)	0.12614297285382614
#   (1, 15796)	0.044892038715669255
#   (1, 56502)	0.043401682412473296
#   (1, 50873)	0.05610093876430879
#   (1, 50796)	0.040567373853097416
#   (1, 55637)	0.07776902403548425
#   (1, 6071)	0.03236408642002072
#   (1, 4586)	0.03196909588782156
#   (1, 31456)	0.0487576235576821
#   (1, 15991)	0.3184132232624777
#   (1, 44720)	0.4552203038932356
#   (1, 25232)	0.07987062912220629
#   (1, 52156)	0.10613499047289007
#   (1, 46216)	0.054135370264246266
#   (1, 21668)	0.10336168148509725
#   (1, 25641)	0.11248669694582579
#   (1, 35959)	0.28283118178257416
#   (1, 35428)	0.11557897264336346
#   (1, 23913)	0.056744131088339284
#   (1, 4869)	0.03313213051770831
#   (1, 21988)	0.1946852040742957
#   (1, 50707)	0.1885808537739778
# ...

# %%
count_x_train[0]
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 0 stored elements and shape (1, 57227)>

# %%
import pickle
load= pickle.load(open("final_model_tf-idf.sav", 'rb'))

# %%
load.predict(count_x_train[0])
# Out:
# array(['FAKE'], dtype='<U4')
